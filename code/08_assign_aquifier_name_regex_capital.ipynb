# %%
import pandas as pd
import re
import csv
from IPython.display import display, clear_output
import geopandas

# %%
def filter_aquifer_name_capitals(tokens, index):
    lowerIndex = higherIndex = index
    afterPreps = ["in", "on", "at", "of", "under", "over", "through", "for"]
    beginningArticles = ["the", "a", "an"]
    
    for i in range(max(0, index-4), index):
        word = tokens[i]
        if word[0].isupper():
            if (lowerIndex == index and index - i <= 2) or (lowerIndex == i+1):
                lowerIndex = i 
    
    for i in range(index, min(index+4, len(tokens))):
        word = tokens[i]
        if (i == index + 1) and (word.lower() == "the" or (word.lower() not in afterPreps)):
            break
        if word[0].isupper():
            if (higherIndex == index and i - index <= 2) or (higherIndex == i-1):
                higherIndex = i
                
    if len(tokens[lowerIndex:higherIndex + 1]) <= 1 or tokens[higherIndex].lower() in afterPreps or ((higherIndex-lowerIndex)<=1 and tokens[lowerIndex].lower() in beginningArticles):
        return None 
    
    return " ".join(tokens[lowerIndex:higherIndex + 1])

# %%
def match_aquifer_name_regex(text):
    aquifer_match_plural = re.findall('(?:[^ ]+ ){0,3}aquifers(?: [^ ]+){0,3}', str(text))
    basin_match_plural = re.findall('(?:[^ ]+ ){0,3}basins(?: [^ ]+){0,3}', str(text)) 
    aquifer_match = re.findall('(?:[^ ]+ ){0,3}aquifer(?: [^ ]+){0,3}', str(text))
    basin_match = re.findall('(?:[^ ]+ ){0,3}basin(?: [^ ]+){0,3}', str(text)) 
    all_matches = aquifer_match + basin_match + basin_match_plural  + basin_match_plural
    if len(all_matches) < 1:
        return float('NaN')
    return all_matches

# %%
def match_aquifer_names_capitals(text):
    tokens = text.split()
    keywords = ['aquifer', 'Aquifer', 'basin', 'Basin', 'aquifers', 'Aquifers', 'basins', 'Basins']
    indexes = [i for i in range(len(tokens)) if tokens[i] in keywords]
    all_matches = [filter_aquifer_name_capitals(tokens, index) for index in indexes]
    all_matches_cleaned = [x for x in all_matches if x is not None]
            
    if all_matches_cleaned == []:
        return float('NaN')
    return all_matches_cleaned

# %%
def match_usgs_list(arr):
    if(type(arr)) is float:
        return float('NaN')
    matches = []
    for element in arr:
        with open('../list_of_aquifer_names_usgs.txt', 'r') as aquifer_names:
            for line in aquifer_names:
                print(line.lower())
                print(element.lower())
                if(line.lower() in element.lower()):
                     matches.append(line)
    if(len(matches) < 1):
        return float('NaN')
    return matches

# %%
df = pd.read_csv('../results/abstracts_cleaned_tokenized_geo_new_oct_5.csv')
display(df.head())
# Out:
#                                        original_text  \
# 0  FRACTURING AND SUBSIDENCE OF THE LAND SURFACE ...
# 1  An analysis of instabilities caused by salinit...
# 2  Pollution of the Rhine and water supply DutchA...
# 3  DEVELOPMENT AND IN PLACE LEACHING OF MOUNTAIN ...
# 4  The study of groundwater movement in boreholes...
#
#                                                 text  \
# 0  fracturing and subsidence of the land surface ...
# 1  an analysis of instabilities caused by salinit...
# 2  pollution of the rhine and water supply dutcha...
# 3  development and in place leaching of mountain ...
# 4  the study of groundwater movement in boreholes...
#
#                                       tokenized_text  \
# 0  ['fracturing', 'and', 'subsidence', 'of', 'the...
# 1  ['an', 'analysis', 'of', 'instabilities', 'cau...
# 2  ['pollution', 'of', 'the', 'rhine', 'and', 'wa...
# 3  ['development', 'and', 'in', 'place', 'leachin...
# 4  ['the', 'study', 'of', 'groundwater', 'movemen...
#
#                          no_stopwords_tokenized_text  \
# 0  ['fracturing', 'subsidence', 'land', 'surface'...
# 1  ['analysis', 'instabilities', 'caused', 'salin...
# 2  ['pollution', 'rhine', 'water', 'supply', 'dut...
# 3  ['development', 'place', 'leaching', 'mountain...
# 4  ['study', 'groundwater', 'movement', 'borehole...
#
#                                    no_stopwords_text  \
# 0  fracturing subsidence land surface caused with...
# 1  analysis instabilities caused salinity gradien...
# 2  pollution rhine water supply dutcha water supp...
# 3  development place leaching mountain city chalc...
# 4  study groundwater movement boreholes performed...
#
#                                                  tdm  \
# 0     amount  aquifers  area  artesian  bench  bo...
# 1     always  amplitude  analyse  analysis  aquif...
# 2     activities  almost  approximately  article ...
# 3     aid  analyzed  annualized  approximately  b...
# 4     among  aquifers  authors  avoiding  based  ...
#
#                                            countries
# 0                                                NaN
# 1                                                NaN
# 2  ['united kingdom of great britain and northern...
# 3                       ['united states of america']
# 4                                          ['spain']

# %%
display(df.tail())
# Out:
#                                            original_text  \
# 65429  Conceptual uncertainties in solubility calcula...
# 65430  From political to environmental conflict in th...
# 65431  Fissure behavior in the chihuahuan desert and ...
# 65432  Integrated study of the Judy Field Block a  an...
# 65433  Land farm design and management in Bolivia A c...
#
#                                                     text  \
# 65429  conceptual uncertainties in solubility calcula...
# 65430  from political to environmental conflict in th...
# 65431  fissure behavior in the chihuahuan desert and ...
# 65432  integrated study of the judy field block a  an...
# 65433  land farm design and management in bolivia a c...
#
#                                           tokenized_text  \
# 65429  ['conceptual', 'uncertainties', 'in', 'solubil...
# 65430  ['from', 'political', 'to', 'environmental', '...
# 65431  ['fissure', 'behavior', 'in', 'the', 'chihuahu...
# 65432  ['integrated', 'study', 'of', 'the', 'judy', '...
# 65433  ['land', 'farm', 'design', 'and', 'management'...
#
#                              no_stopwords_tokenized_text  \
# 65429  ['conceptual', 'uncertainties', 'solubility', ...
# 65430  ['political', 'environmental', 'conflict', 'de...
# 65431  ['fissure', 'behavior', 'chihuahuan', 'desert'...
# 65432  ['integrated', 'study', 'judy', 'field', 'bloc...
# 65433  ['land', 'farm', 'design', 'management', 'boli...
#
#                                        no_stopwords_text  \
# 65429  conceptual uncertainties solubility calculatio...
# 65430  political environmental conflict development t...
# 65431  fissure behavior chihuahuan desert depth estim...
# 65432  integrated study judy field block overpressure...
# 65433  land farm design management bolivia casestudya...
#
#                                                      tdm  \
# 65429     account  actinide  also  analysis  answers ...
# 65430     achieve  activity  along  among  aquifers  ...
# 65431     aquifers  authors  base  become  behavior  ...
# 65432     accumulation  across  ago  allows  almost  ...
# 65433     abstract  acceptable  accomplished  additio...
#
#                           countries
# 65429                           NaN
# 65430                    ['israel']
# 65431  ['united states of america']
# 65432                           NaN
# 65433       ['argentina', 'norway']

# %%
df['aquifer_mentions_capital_algorithm'] = df['original_text'].apply(lambda x: match_aquifer_names_capitals(x))
df['aquifer_mentions_regex_algorithm'] = df['text'].apply(lambda x: match_aquifer_name_regex(x))

# %%
display(df.head())
# Out:
#                                        original_text  \
# 0  FRACTURING AND SUBSIDENCE OF THE LAND SURFACE ...
# 1  An analysis of instabilities caused by salinit...
# 2  Pollution of the Rhine and water supply DutchA...
# 3  DEVELOPMENT AND IN PLACE LEACHING OF MOUNTAIN ...
# 4  The study of groundwater movement in boreholes...
#
#                                                 text  \
# 0  fracturing and subsidence of the land surface ...
# 1  an analysis of instabilities caused by salinit...
# 2  pollution of the rhine and water supply dutcha...
# 3  development and in place leaching of mountain ...
# 4  the study of groundwater movement in boreholes...
#
#                                       tokenized_text  \
# 0  ['fracturing', 'and', 'subsidence', 'of', 'the...
# 1  ['an', 'analysis', 'of', 'instabilities', 'cau...
# 2  ['pollution', 'of', 'the', 'rhine', 'and', 'wa...
# 3  ['development', 'and', 'in', 'place', 'leachin...
# 4  ['the', 'study', 'of', 'groundwater', 'movemen...
#
#                          no_stopwords_tokenized_text  \
# 0  ['fracturing', 'subsidence', 'land', 'surface'...
# 1  ['analysis', 'instabilities', 'caused', 'salin...
# 2  ['pollution', 'rhine', 'water', 'supply', 'dut...
# 3  ['development', 'place', 'leaching', 'mountain...
# 4  ['study', 'groundwater', 'movement', 'borehole...
#
#                                    no_stopwords_text  \
# 0  fracturing subsidence land surface caused with...
# 1  analysis instabilities caused salinity gradien...
# 2  pollution rhine water supply dutcha water supp...
# 3  development place leaching mountain city chalc...
# 4  study groundwater movement boreholes performed...
#
#                                                  tdm  \
# 0     amount  aquifers  area  artesian  bench  bo...
# 1     always  amplitude  analyse  analysis  aquif...
# 2     activities  almost  approximately  article ...
# 3     aid  analyzed  annualized  approximately  b...
# 4     among  aquifers  authors  avoiding  based  ...
#
#                                            countries  \
# 0                                                NaN
# 1                                                NaN
# 2  ['united kingdom of great britain and northern...
# 3                       ['united states of america']
# 4                                          ['spain']
#
#   aquifer_mentions_capital_algorithm  \
# 0                                NaN
# 1                                NaN
# 2                                NaN
# 3                                NaN
# 4                                NaN
#
#                     aquifer_mentions_regex_algorithm
# 0                       [the lower artesian aquifer]
# 1  [transport through the aquifer is considerably...
# 2                                                NaN
# 3                                                NaN
# 4  [of the groundwater aquifer, the dam ii basin ...

# %%
counter = 0
matched = 0; 
for row in df.itertuples():
    #nan is type float
  if type(row[8])is not float:
#         print(row[8])
#         counter +=1
        matched += 1 
print(matched)
print(len(df.index))
print(matched/len(df.index))
# Out:
# 10538
# 65434
# 0.16104777332885045

# %%
print(df.loc[0, 'original_text'])
# Out:
# FRACTURING AND SUBSIDENCE OF THE LAND SURFACE CAUSED BY THE WITHDRAWAL OF GROUND WATER IN THE MILFORD AREA UTAHLand subsidence in the Milford area is demonstrated by three lines of evidence  collapse structures  well casings that protrude higher above the land surface than when first placed in the borehole and  lower elevations at National Ocean Survey formerly U S Coast and Geodetic Survey bench marks in  than in  This evidence shows that land subsidence in the Milford area is of two types each having a different origin One type has a nearsurface origin in the claysilt zone in the upper part of the principal groundwater reservoir and the other is in the lower artesian aquifers of the principal groundwater reservoir The amount of observed subsidence ranges from   ft   m at the bench mark at Read to about  ft   m at collapse structures in the Hay Springs area

# %%
aquiferDf_regex= df.dropna(subset=["aquifer_mentions_regex_algorithm"])
aquiferDf_regex["aquifer_mentions_regex_algorithm"].to_csv("../results/aquifer_names_regex_algorithm.csv")    
display(aquiferDf_regex.head(5))
# Out:
# /Users/neel/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: FutureWarning: The signature of `Series.to_csv` was aligned to that of `DataFrame.to_csv`, and argument 'header' will change its default value from False to True: please pass an explicit value to suppress this warning.
#                                        original_text  \
# 0  FRACTURING AND SUBSIDENCE OF THE LAND SURFACE ...
# 1  An analysis of instabilities caused by salinit...
# 4  The study of groundwater movement in boreholes...
# 5  Groundwater study of a volcanic area near Band...
# 8  AVAILABILITY OF WATER FOR COAL CONVERSIONCoal ...
#
#                                                 text  \
# 0  fracturing and subsidence of the land surface ...
# 1  an analysis of instabilities caused by salinit...
# 4  the study of groundwater movement in boreholes...
# 5  groundwater study of a volcanic area near band...
# 8  availability of water for coal conversioncoal ...
#
#                                       tokenized_text  \
# 0  ['fracturing', 'and', 'subsidence', 'of', 'the...
# 1  ['an', 'analysis', 'of', 'instabilities', 'cau...
# 4  ['the', 'study', 'of', 'groundwater', 'movemen...
# 5  ['groundwater', 'study', 'of', 'a', 'volcanic'...
# 8  ['availability', 'of', 'water', 'for', 'coal',...
#
#                          no_stopwords_tokenized_text  \
# 0  ['fracturing', 'subsidence', 'land', 'surface'...
# 1  ['analysis', 'instabilities', 'caused', 'salin...
# 4  ['study', 'groundwater', 'movement', 'borehole...
# 5  ['groundwater', 'study', 'volcanic', 'area', '...
# 8  ['availability', 'water', 'coal', 'conversionc...
#
#                                    no_stopwords_text  \
# 0  fracturing subsidence land surface caused with...
# 1  analysis instabilities caused salinity gradien...
# 4  study groundwater movement boreholes performed...
# 5  groundwater study volcanic area near bandung j...
# 8  availability water coal conversioncoal abundan...
#
#                                                  tdm  \
# 0     amount  aquifers  area  artesian  bench  bo...
# 1     always  amplitude  analyse  analysis  aquif...
# 4     among  aquifers  authors  avoiding  based  ...
# 5     abundant  activities  analysis  aquifers  a...
# 8     abundant  allocates  alternative  availabil...
#
#                       countries  \
# 0                           NaN
# 1                           NaN
# 4                     ['spain']
# 5                 ['indonesia']
# 8  ['united states of america']
#
#                aquifer_mentions_capital_algorithm  \
# 0                                             NaN
# 1                                             NaN
# 4                                             NaN
# 5                                             NaN
# 8  [Missouri River Basin, Fort UnionPowder Basin]
#
#                     aquifer_mentions_regex_algorithm
# 0                       [the lower artesian aquifer]
# 1  [transport through the aquifer is considerably...
# 4  [of the groundwater aquifer, the dam ii basin ...
# 5         [concerning rainfall infiltration aquifer]
# 8  [upper missouri river basin and tributaries ye...

# %%
aquiferDf_capitals = df.dropna(subset=["aquifer_mentions_capital_algorithm"])
aquiferDf_capitals["aquifer_mentions_capital_algorithm"].to_csv("../results/aquifer_names_capital_algorithm.csv")    
display(aquiferDf_capitals.head(5))
# Out:
# /Users/neel/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: FutureWarning: The signature of `Series.to_csv` was aligned to that of `DataFrame.to_csv`, and argument 'header' will change its default value from False to True: please pass an explicit value to suppress this warning.
#                                         original_text  \
# 8   AVAILABILITY OF WATER FOR COAL CONVERSIONCoal ...
# 25  COMPARATIVE ECONOMICS AND ENERGY REQUIREMENTS ...
# 27  Comparative economics and enrgy requirements o...
# 49  A Seismic Ground  Water Survey in New Hampshir...
# 58  STRATIGRAPHIC AND HYDROLOGIC RELATIONSHIP OF T...
#
#                                                  text  \
# 8   availability of water for coal conversioncoal ...
# 25  comparative economics and energy requirements ...
# 27  comparative economics and enrgy requirements o...
# 49  a seismic ground  water survey in new hampshir...
# 58  stratigraphic and hydrologic relationship of t...
#
#                                        tokenized_text  \
# 8   ['availability', 'of', 'water', 'for', 'coal',...
# 25  ['comparative', 'economics', 'and', 'energy', ...
# 27  ['comparative', 'economics', 'and', 'enrgy', '...
# 49  ['a', 'seismic', 'ground', 'water', 'survey', ...
# 58  ['stratigraphic', 'and', 'hydrologic', 'relati...
#
#                           no_stopwords_tokenized_text  \
# 8   ['availability', 'water', 'coal', 'conversionc...
# 25  ['comparative', 'economics', 'energy', 'requir...
# 27  ['comparative', 'economics', 'enrgy', 'require...
# 49  ['seismic', 'ground', 'water', 'survey', 'new'...
# 58  ['stratigraphic', 'hydrologic', 'relationship'...
#
#                                     no_stopwords_text  \
# 8   availability water coal conversioncoal abundan...
# 25  comparative economics energy requirements vari...
# 27  comparative economics enrgy requirements vario...
# 49  seismic ground water survey new hampshirethe d...
# 58  stratigraphic hydrologic relationship piney po...
#
#                                                   tdm  \
# 8      abundant  allocates  alternative  availabil...
# 25     alone  ana  annual  aquifers  assumed  avai...
# 27     alone  ana  annual  aquifers  assumed  avai...
# 49     according  along  anomalies  apparently  at...
# 58     acts  alloway  altitude  analyses  aquifer ...
#
#                                             countries  \
# 8                        ['united states of america']
# 25               ['peru', 'united states of america']
# 27               ['peru', 'united states of america']
# 49  ['united kingdom of great britain and northern...
# 58             ['jersey', 'united states of america']
#
#                    aquifer_mentions_capital_algorithm  \
# 8      [Missouri River Basin, Fort UnionPowder Basin]
# 25                          [River groundwater basin]
# 27                          [River groundwater basin]
# 49    [HampshireThe drainage basin of Barbadoes Pond]
# 58  [Piney Point aquifer, Piney Point aquifer in C...
#
#                      aquifer_mentions_regex_algorithm
# 8   [upper missouri river basin and tributaries ye...
# 25  [recharge of highquality aquifer, ana river gr...
# 27  [recharge of highquality aquifer, ana river gr...
# 49  [new hampshirethe drainage basin of barbadoes ...
# 58  [the piney point aquifer and the alloway, the ...

# %%
# df['usgs_aquifer_matches'] = df['aquifer_mentions'].apply(lambda x: match_usgs_list(x))

# %%
# matchDf = df.dropna(subset=["usgs_aquifer_matches"])
# display(matchDf.head())

# %%
geo_df = geopandas.read_file("../data/WHYMAP_shapefiles/whymap_GW_aquifers_v1_poly.shp")

# %%
pd.set_option('display.max_columns', 999)
display(geo_df.head(30))
# Out:
#     HYGEO2  ICE  CONTINENT                                           geometry
# 0       33   88         99  POLYGON ((-27.61889 81.47500, -27.84575 81.464...
# 1       33   88         99  POLYGON ((-39.03056 83.28638, -39.17389 83.286...
# 2       33   88         99  POLYGON ((-38.84028 83.10748, -38.89918 83.108...
# 3       33   88         99  POLYGON ((-41.25250 83.28526, -41.39028 83.292...
# 4       33   88         99  POLYGON ((-42.14888 83.24136, -42.38194 83.245...
# 5       33   88         99  POLYGON ((-41.15944 83.20665, -41.31555 83.207...
# 6       33   88         99  POLYGON ((-38.35888 83.13275, -38.46112 83.133...
# 7       33   88         99  POLYGON ((-39.87528 82.97861, -39.88861 82.979...
# 8       33   88         99  POLYGON ((-39.61389 82.99444, -39.70306 82.996...
# 9       33   88          1  POLYGON ((-76.23083 82.44470, -76.18417 82.453...
# 10      33   88          1  POLYGON ((-78.36581 82.88360, -78.38332 82.883...
# 11      33   88         99  POLYGON ((-46.53279 82.83055, -46.63306 82.831...
# 12      33   88         99  POLYGON ((-47.79029 82.77748, -47.90333 82.779...
# 13      33   88         99  POLYGON ((-45.04000 82.05359, -45.07667 82.055...
# 14      33   88         99  POLYGON ((-48.21250 82.39583, -48.23861 82.395...
# 15      33   88         99  POLYGON ((-51.57556 81.96609, -51.63890 81.966...
# 16      33   88         99  POLYGON ((-52.00778 82.20750, -52.08777 82.208...
# 17      33   88         99  POLYGON ((-18.87167 81.97331, -18.89972 81.974...
# 18      33   88         99  POLYGON ((-19.84917 81.86915, -19.96666 81.871...
# 19      33   88         99  POLYGON ((-16.91556 81.85610, -17.05438 81.836...
# 20      88   88         99  POLYGON ((-27.61889 81.47500, -27.57750 81.464...
# 21      88   88         99  POLYGON ((-13.17351 81.38351, -13.24297 81.395...
# 22      33   89          3  POLYGON ((58.06137 81.68776, 57.98055 81.68858...
# 23      33   88         99  POLYGON ((-18.58555 81.64665, -18.60555 81.646...
# 24      33   88         99  POLYGON ((-20.93055 81.60636, -20.81722 81.627...
# 25      33   89          3  POLYGON ((63.47083 81.58250, 63.42915 81.58415...
# 26      33   88         99  POLYGON ((-13.17351 81.38351, -13.20639 81.371...
# 27      33   89          3  POLYGON ((58.45555 81.55693, 58.42028 81.55888...
# 28      33   88          1  POLYGON ((-91.76166 81.54803, -91.80139 81.548...
# 29      33   89          3  POLYGON ((62.00721 81.54220, 61.96748 81.54304...

# %%
for col in geo_df.columns: 
    print(col)
# Out:
# HYGEO2
# ICE
# CONTINENT
# geometry

# %%
print(geo_df.loc[2,'geometry'])
# Out:
# POLYGON ((-38.84027676799997 83.10748143300003, -38.89917674299994 83.10833672400008, -38.93666417999998 83.11137962200007, -38.94833094199998 83.11359548600007, -39.05777464899995 83.12637666600006, -39.10083445399994 83.12996980900004, -39.21250018099994 83.13304415500005, -39.49306219599998 83.14804379600008, -39.58306518599994 83.15611016600008, -39.82583369999998 83.19385843600008, -39.88416262699997 83.20972242900007, -39.88861544599996 83.21582632500008, -39.92471538299998 83.23275245600007, -40.01722503199994 83.25167074300003, -40.05193714599994 83.25610650000004, -40.08417082199998 83.25750524600005, -40.11194751099998 83.25665750900004, -40.15166920299998 83.25417102900008, -40.19971413399998 83.25277252400008, -40.25444472099997 83.25277252400008, -40.46944536099994 83.25525882500006, -40.53444362499994 83.25832476000005, -40.62694768299997 83.26611186700006, -40.66221357099994 83.27053678900006, -40.66833604799996 83.27443947500007, -40.67333732099996 83.28028083200007, -40.67083549499995 83.29832519000007, -40.66750772199998 83.30330981000003, -40.64805336499995 83.32276493900008, -40.63472109199995 83.32887615800007, -40.60583405399996 83.33776994300007, -40.50889030899998 83.35941865800004, -40.29749915799994 83.34942174400004, -40.27500675699997 83.34470908500003, -40.26472417999997 83.33859286000006, -40.25194370399998 83.33276225300006, -40.23194152999997 83.32748643000008, -40.20444379699995 83.32276493900008, -40.09388062899995 83.30886237600004, -40.05139187699996 83.30498107800008, -40.00445018399995 83.30192191800006, -39.88527383299999 83.29664033800003, -39.76527422099997 83.29331354100003, -39.72638175999998 83.28997316300007, -39.69387942999998 83.28470898900008, -39.67972760499998 83.27971500600006, -39.65583972099995 83.26833127100008, -39.64611985199997 83.26221085600008, -39.63944044599998 83.25665750900004, -39.62777457499993 83.25110575100007, -39.58889349599997 83.24054342900007, -39.54277724199994 83.23026903400006, -39.48916553599997 83.22026800800006, -39.42861292699996 83.21082183400006, -39.39445047499999 83.20638230800006, -39.35306259999993 83.20221148500008, -39.18027820499998 83.18580458900004, -39.07861483099998 83.17942864200006, -38.96222532699994 83.17360344200006, -38.86388733799998 83.17191530300005, -38.83194385799993 83.17025544300003, -38.79944360799993 83.16720335700006, -38.64722353999997 83.12053921700004, -38.63971971099994 83.11581160100008, -38.66306016599998 83.11276801300005, -38.84027676799997 83.10748143300003))

# %%
geo_df.plot(column= 'HYGEO2')

# %%
df.drop("aquifer_mentions_regex_algorithm", axis=1, inplace=True)
df.to_csv("../dataframes/12_2_capital_algorithms.csv")
