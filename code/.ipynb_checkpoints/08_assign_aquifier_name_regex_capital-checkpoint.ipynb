# %%
import pandas as pd
import re
import csv
from IPython.display import display, clear_output

# %%
def filter_aquifer_name(tokens, index):
    lowerIndex = higherIndex = index
    afterPreps = ["in", "on", "at", "of", "under", "over", "through", "for"]
    beginningArticles = ["the", "a", "an"]
    
    for i in range(max(0, index-4), index):
        word = tokens[i]
        if word[0].isupper():
            if (lowerIndex == index and index - i <= 2) or (lowerIndex == i+1):
                lowerIndex = i 
    
    for i in range(index, min(index+4, len(tokens))):
        word = tokens[i]
        if (i == index + 1) and (word.lower() == "the" or (word.lower() not in afterPreps)):
            break
        if word[0].isupper():
            if (higherIndex == index and i - index <= 2) or (higherIndex == i-1):
                higherIndex = i
                
    if len(tokens[lowerIndex:higherIndex + 1]) <= 1 or tokens[higherIndex].lower() in afterPreps or ((higherIndex-lowerIndex)<=1 and tokens[lowerIndex].lower() in beginningArticles):
        return None 
    
    return " ".join(tokens[lowerIndex:higherIndex + 1])

# %%
def match_aquifer_names(text):
#     aquifer_match_plural = re.findall('(?:[^ ]+ ){0,3}aquifer(?: [^ ]+){0,3}', str(text))
#     aquifer_caps_match_plural = re.findall('(?:[^ ]+ ){0,3}Aquifer(?: [^ ]+){0,3}', str(text))
#     basin_match_plural = re.findall('(?:[^ ]+ ){0,3}basin(?: [^ ]+){0,3}', str(text)) 
#     basin_caps_match_plural = re.findall('(?:[^ ]+ ){0,3}Basin(?: [^ ]+){0,3}', str(text))
    
#     aquifer_match = re.findall('(?:[^ ]+ ){0,3}aquifer(?: [^ ]+){0,3}', str(text))
#     aquifer_caps_match = re.findall('(?:[^ ]+ ){0,3}Aquifer(?: [^ ]+){0,3}', str(text))
#     basin_match = re.findall('(?:[^ ]+ ){0,3}basin(?: [^ ]+){0,3}', str(text)) 
#     basin_caps_match = re.findall('(?:[^ ]+ ){0,3}Basin(?: [^ ]+){0,3}', str(text))
#     all_matches = aquifer_match + basin_match + aquifer_caps_match + basin_caps_match
#     if len(all_matches) < 1:
#         return "NA"
    tokens = text.split()
    keywords = ['aquifer', 'Aquifer', 'basin', 'Basin', 'aquifers', 'Aquifers', 'basins', 'Basins']
    indexes = [i for i in range(len(tokens)) if tokens[i] in keywords]
    all_matches = [filter_aquifer_name(tokens, index) for index in indexes]
    all_matches_cleaned = [x for x in all_matches if x is not None]
            
    if all_matches_cleaned == []:
        return float('NaN')
    return all_matches_cleaned

# %%
df = pd.read_csv('../results/abstracts_cleaned_tokenized_geo_new_oct_5.csv')
display(df.head())
# Out:
#                                        original_text  \
# 0  FRACTURING AND SUBSIDENCE OF THE LAND SURFACE ...
# 1  An analysis of instabilities caused by salinit...
# 2  Pollution of the Rhine and water supply DutchA...
# 3  DEVELOPMENT AND IN PLACE LEACHING OF MOUNTAIN ...
# 4  The study of groundwater movement in boreholes...
#
#                                                 text  \
# 0  fracturing and subsidence of the land surface ...
# 1  an analysis of instabilities caused by salinit...
# 2  pollution of the rhine and water supply dutcha...
# 3  development and in place leaching of mountain ...
# 4  the study of groundwater movement in boreholes...
#
#                                       tokenized_text  \
# 0  ['fracturing', 'and', 'subsidence', 'of', 'the...
# 1  ['an', 'analysis', 'of', 'instabilities', 'cau...
# 2  ['pollution', 'of', 'the', 'rhine', 'and', 'wa...
# 3  ['development', 'and', 'in', 'place', 'leachin...
# 4  ['the', 'study', 'of', 'groundwater', 'movemen...
#
#                          no_stopwords_tokenized_text  \
# 0  ['fracturing', 'subsidence', 'land', 'surface'...
# 1  ['analysis', 'instabilities', 'caused', 'salin...
# 2  ['pollution', 'rhine', 'water', 'supply', 'dut...
# 3  ['development', 'place', 'leaching', 'mountain...
# 4  ['study', 'groundwater', 'movement', 'borehole...
#
#                                    no_stopwords_text  \
# 0  fracturing subsidence land surface caused with...
# 1  analysis instabilities caused salinity gradien...
# 2  pollution rhine water supply dutcha water supp...
# 3  development place leaching mountain city chalc...
# 4  study groundwater movement boreholes performed...
#
#                                                  tdm  \
# 0     amount  aquifers  area  artesian  bench  bo...
# 1     always  amplitude  analyse  analysis  aquif...
# 2     activities  almost  approximately  article ...
# 3     aid  analyzed  annualized  approximately  b...
# 4     among  aquifers  authors  avoiding  based  ...
#
#                                            countries
# 0                                                NaN
# 1                                                NaN
# 2  ['united kingdom of great britain and northern...
# 3                       ['united states of america']
# 4                                          ['spain']

# %%
display(df.tail(50))
# Out:
#                                            original_text  \
# 65384  Uisge Meinne Mine water hydrogeology in the Ce...
# 65385  The Hungarian water management and its strateg...
# 65386  Study of hydrocarbon contamination using multi...
# 65387  Understanding mass transfer at the pore scaleN...
# 65388  Hookeria lucens a new record for the moss flor...
# 65389  Chloride Mass Balance to determine water fluxe...
# 65390  Life in glacial and alpine rivers in central i...
# 65391  Numerical modeling of steam injection into sat...
# 65392  Enhanced oil recovery with high pressure nitro...
# 65393  Committee report Disinfection at large and med...
# 65394  Pressure filtration for iron  manganese remova...
# 65395  Systematicity in thermodynamics and kinetics w...
# 65396  An evaluation of MTBE occurrence at fuel leak ...
# 65397  Conservation policy for the future What lesson...
# 65398  Vadose zone monitoring system for site charact...
# 65399  Sorption distribution coefficients Discrepancy...
# 65400  Phylogenetic reconstruction of the subterranea...
# 65401  Automated D mapping of submarine tunnelsAdvanc...
# 65402  Lookback on Performance of  Horizontal Wells T...
# 65403  Lookback on Performance of  Horizontal Wells T...
# 65404  Square pegs round holes and slow desorptionPre...
# 65405  Automated D mapping of SubmarineTunnelsAdvance...
# 65406  An inversion for fluid transport properties of...
# 65407  Practical applications of time domain reflecto...
# 65408  Management of organic amendments in vegetable ...
# 65409  Bacteriological and Parasitological Pollution ...
# 65410  Phytoremediaion of methyltbutyl ether MTBELarg...
# 65411  Biotic and abiotic degradation of tetrachloroe...
# 65412  A regulatory response to the MTBE threat to gr...
# 65413  WARSYP A robust modeling approach for water re...
# 65414  Oxidative alteration of spent fuel in a silica...
# 65415  The influence of different methods to derive s...
# 65416  Biotechnologies for remediation and pollution ...
# 65417  An intermediatescale lysimeter facility for su...
# 65418  An Overview of ReEntry and Clampon Infill Dril...
# 65419  Producing RichGasCondensate Reservoirs  Case H...
# 65420  Successful west delta block  redevelopment uti...
# 65421  Application of D streamline methodology in the...
# 65422  Successful West Delta Block  redevelopment uti...
# 65423  Mechanism and effect of chemical weathering of...
# 65424  Inclusion of the performance model to direct a...
# 65425  The influence of surfactants and biosurfactant...
# 65426  Fate of anthracene in contaminated soil  Trans...
# 65427  Spring season pattern of nitrateN and herbicid...
# 65428  Estimation of potential loss of two pesticides...
# 65429  Conceptual uncertainties in solubility calcula...
# 65430  From political to environmental conflict in th...
# 65431  Fissure behavior in the chihuahuan desert and ...
# 65432  Integrated study of the Judy Field Block a  an...
# 65433  Land farm design and management in Bolivia A c...
#
#                                                     text  \
# 65384  uisge meinne mine water hydrogeology in the ce...
# 65385  the hungarian water management and its strateg...
# 65386  study of hydrocarbon contamination using multi...
# 65387  understanding mass transfer at the pore scalen...
# 65388  hookeria lucens a new record for the moss flor...
# 65389  chloride mass balance to determine water fluxe...
# 65390  life in glacial and alpine rivers in central i...
# 65391  numerical modeling of steam injection into sat...
# 65392  enhanced oil recovery with high pressure nitro...
# 65393  committee report disinfection at large and med...
# 65394  pressure filtration for iron  manganese remova...
# 65395  systematicity in thermodynamics and kinetics w...
# 65396  an evaluation of mtbe occurrence at fuel leak ...
# 65397  conservation policy for the future what lesson...
# 65398  vadose zone monitoring system for site charact...
# 65399  sorption distribution coefficients discrepancy...
# 65400  phylogenetic reconstruction of the subterranea...
# 65401  automated d mapping of submarine tunnelsadvanc...
# 65402  lookback on performance of  horizontal wells t...
# 65403  lookback on performance of  horizontal wells t...
# 65404  square pegs round holes and slow desorptionpre...
# 65405  automated d mapping of submarinetunnelsadvance...
# 65406  an inversion for fluid transport properties of...
# 65407  practical applications of time domain reflecto...
# 65408  management of organic amendments in vegetable ...
# 65409  bacteriological and parasitological pollution ...
# 65410  phytoremediaion of methyltbutyl ether mtbelarg...
# 65411  biotic and abiotic degradation of tetrachloroe...
# 65412  a regulatory response to the mtbe threat to gr...
# 65413  warsyp a robust modeling approach for water re...
# 65414  oxidative alteration of spent fuel in a silica...
# 65415  the influence of different methods to derive s...
# 65416  biotechnologies for remediation and pollution ...
# 65417  an intermediatescale lysimeter facility for su...
# 65418  an overview of reentry and clampon infill dril...
# 65419  producing richgascondensate reservoirs  case h...
# 65420  successful west delta block  redevelopment uti...
# 65421  application of d streamline methodology in the...
# 65422  successful west delta block  redevelopment uti...
# 65423  mechanism and effect of chemical weathering of...
# 65424  inclusion of the performance model to direct a...
# 65425  the influence of surfactants and biosurfactant...
# 65426  fate of anthracene in contaminated soil  trans...
# 65427  spring season pattern of nitraten and herbicid...
# 65428  estimation of potential loss of two pesticides...
# 65429  conceptual uncertainties in solubility calcula...
# 65430  from political to environmental conflict in th...
# 65431  fissure behavior in the chihuahuan desert and ...
# 65432  integrated study of the judy field block a  an...
# 65433  land farm design and management in bolivia a c...
#
#                                           tokenized_text  \
# 65384  ['uisge', 'meinne', 'mine', 'water', 'hydrogeo...
# 65385  ['the', 'hungarian', 'water', 'management', 'a...
# 65386  ['study', 'of', 'hydrocarbon', 'contamination'...
# 65387  ['understanding', 'mass', 'transfer', 'at', 't...
# 65388  ['hookeria', 'lucens', 'a', 'new', 'record', '...
# 65389  ['chloride', 'mass', 'balance', 'to', 'determi...
# 65390  ['life', 'in', 'glacial', 'and', 'alpine', 'ri...
# 65391  ['numerical', 'modeling', 'of', 'steam', 'inje...
# 65392  ['enhanced', 'oil', 'recovery', 'with', 'high'...
# 65393  ['committee', 'report', 'disinfection', 'at', ...
# 65394  ['pressure', 'filtration', 'for', 'iron', 'man...
# 65395  ['systematicity', 'in', 'thermodynamics', 'and...
# 65396  ['an', 'evaluation', 'of', 'mtbe', 'occurrence...
# 65397  ['conservation', 'policy', 'for', 'the', 'futu...
# 65398  ['vadose', 'zone', 'monitoring', 'system', 'fo...
# 65399  ['sorption', 'distribution', 'coefficients', '...
# 65400  ['phylogenetic', 'reconstruction', 'of', 'the'...
# 65401  ['automated', 'd', 'mapping', 'of', 'submarine...
# 65402  ['lookback', 'on', 'performance', 'of', 'horiz...
# 65403  ['lookback', 'on', 'performance', 'of', 'horiz...
# 65404  ['square', 'pegs', 'round', 'holes', 'and', 's...
# 65405  ['automated', 'd', 'mapping', 'of', 'submarine...
# 65406  ['an', 'inversion', 'for', 'fluid', 'transport...
# 65407  ['practical', 'applications', 'of', 'time', 'd...
# 65408  ['management', 'of', 'organic', 'amendments', ...
# 65409  ['bacteriological', 'and', 'parasitological', ...
# 65410  ['phytoremediaion', 'of', 'methyltbutyl', 'eth...
# 65411  ['biotic', 'and', 'abiotic', 'degradation', 'o...
# 65412  ['a', 'regulatory', 'response', 'to', 'the', '...
# 65413  ['warsyp', 'a', 'robust', 'modeling', 'approac...
# 65414  ['oxidative', 'alteration', 'of', 'spent', 'fu...
# 65415  ['the', 'influence', 'of', 'different', 'metho...
# 65416  ['biotechnologies', 'for', 'remediation', 'and...
# 65417  ['an', 'intermediatescale', 'lysimeter', 'faci...
# 65418  ['an', 'overview', 'of', 'reentry', 'and', 'cl...
# 65419  ['producing', 'richgascondensate', 'reservoirs...
# 65420  ['successful', 'west', 'delta', 'block', 'rede...
# 65421  ['application', 'of', 'd', 'streamline', 'meth...
# 65422  ['successful', 'west', 'delta', 'block', 'rede...
# 65423  ['mechanism', 'and', 'effect', 'of', 'chemical...
# 65424  ['inclusion', 'of', 'the', 'performance', 'mod...
# 65425  ['the', 'influence', 'of', 'surfactants', 'and...
# 65426  ['fate', 'of', 'anthracene', 'in', 'contaminat...
# 65427  ['spring', 'season', 'pattern', 'of', 'nitrate...
# 65428  ['estimation', 'of', 'potential', 'loss', 'of'...
# 65429  ['conceptual', 'uncertainties', 'in', 'solubil...
# 65430  ['from', 'political', 'to', 'environmental', '...
# 65431  ['fissure', 'behavior', 'in', 'the', 'chihuahu...
# 65432  ['integrated', 'study', 'of', 'the', 'judy', '...
# 65433  ['land', 'farm', 'design', 'and', 'management'...
#
#                              no_stopwords_tokenized_text  \
# 65384  ['uisge', 'meinne', 'mine', 'water', 'hydrogeo...
# 65385  ['hungarian', 'water', 'management', 'strategi...
# 65386  ['study', 'hydrocarbon', 'contamination', 'usi...
# 65387  ['understanding', 'mass', 'transfer', 'pore', ...
# 65388  ['hookeria', 'lucens', 'new', 'record', 'moss'...
# 65389  ['chloride', 'mass', 'balance', 'determine', '...
# 65390  ['life', 'glacial', 'alpine', 'rivers', 'centr...
# 65391  ['numerical', 'modeling', 'steam', 'injection'...
# 65392  ['enhanced', 'oil', 'recovery', 'high', 'press...
# 65393  ['committee', 'report', 'disinfection', 'large...
# 65394  ['pressure', 'filtration', 'iron', 'manganese'...
# 65395  ['systematicity', 'thermodynamics', 'kinetics'...
# 65396  ['evaluation', 'mtbe', 'occurrence', 'fuel', '...
# 65397  ['conservation', 'policy', 'future', 'lessons'...
# 65398  ['vadose', 'zone', 'monitoring', 'system', 'si...
# 65399  ['sorption', 'distribution', 'coefficients', '...
# 65400  ['phylogenetic', 'reconstruction', 'subterrane...
# 65401  ['automated', 'mapping', 'submarine', 'tunnels...
# 65402  ['lookback', 'performance', 'horizontal', 'wel...
# 65403  ['lookback', 'performance', 'horizontal', 'wel...
# 65404  ['square', 'pegs', 'round', 'holes', 'slow', '...
# 65405  ['automated', 'mapping', 'submarinetunnelsadva...
# 65406  ['inversion', 'fluid', 'transport', 'propertie...
# 65407  ['practical', 'applications', 'time', 'domain'...
# 65408  ['management', 'organic', 'amendments', 'veget...
# 65409  ['bacteriological', 'parasitological', 'pollut...
# 65410  ['phytoremediaion', 'methyltbutyl', 'ether', '...
# 65411  ['biotic', 'abiotic', 'degradation', 'tetrachl...
# 65412  ['regulatory', 'response', 'mtbe', 'threat', '...
# 65413  ['warsyp', 'robust', 'modeling', 'approach', '...
# 65414  ['oxidative', 'alteration', 'spent', 'fuel', '...
# 65415  ['influence', 'different', 'methods', 'derive'...
# 65416  ['biotechnologies', 'remediation', 'pollution'...
# 65417  ['intermediatescale', 'lysimeter', 'facility',...
# 65418  ['overview', 'reentry', 'clampon', 'infill', '...
# 65419  ['producing', 'richgascondensate', 'reservoirs...
# 65420  ['successful', 'west', 'delta', 'block', 'rede...
# 65421  ['application', 'streamline', 'methodology', '...
# 65422  ['successful', 'west', 'delta', 'block', 'rede...
# 65423  ['mechanism', 'effect', 'chemical', 'weatherin...
# 65424  ['inclusion', 'performance', 'model', 'direct'...
# 65425  ['influence', 'surfactants', 'biosurfactants',...
# 65426  ['fate', 'anthracene', 'contaminated', 'soil',...
# 65427  ['spring', 'season', 'pattern', 'nitraten', 'h...
# 65428  ['estimation', 'potential', 'loss', 'two', 'pe...
# 65429  ['conceptual', 'uncertainties', 'solubility', ...
# 65430  ['political', 'environmental', 'conflict', 'de...
# 65431  ['fissure', 'behavior', 'chihuahuan', 'desert'...
# 65432  ['integrated', 'study', 'judy', 'field', 'bloc...
# 65433  ['land', 'farm', 'design', 'management', 'boli...
#
#                                        no_stopwords_text  \
# 65384  uisge meinne mine water hydrogeology celtic la...
# 65385  hungarian water management strategic driving f...
# 65386  study hydrocarbon contamination using multilev...
# 65387  understanding mass transfer pore scalenonaqueo...
# 65388  hookeria lucens new record moss flora iceland ...
# 65389  chloride mass balance determine water fluxes b...
# 65390  life glacial alpine rivers central iceland rel...
# 65391  numerical modeling steam injection saturated p...
# 65392  enhanced oil recovery high pressure nitrogen i...
# 65393  committee report disinfection large mediumsize...
# 65394  pressure filtration iron manganese removalconc...
# 65395  systematicity thermodynamics kinetics ether st...
# 65396  evaluation mtbe occurrence fuel leak sites ope...
# 65397  conservation policy future lessons learned wat...
# 65398  vadose zone monitoring system site characteriz...
# 65399  sorption distribution coefficients discrepancy...
# 65400  phylogenetic reconstruction subterranean amphi...
# 65401  automated mapping submarine tunnelsadvances em...
# 65402  lookback performance horizontal wells targetin...
# 65403  lookback performance horizontal wells targetin...
# 65404  square pegs round holes slow desorptionpredict...
# 65405  automated mapping submarinetunnelsadvances emb...
# 65406  inversion fluid transport properties threedime...
# 65407  practical applications time domain reflectomet...
# 65408  management organic amendments vegetable crop p...
# 65409  bacteriological parasitological pollution natu...
# 65410  phytoremediaion methyltbutyl ether mtbelargesc...
# 65411  biotic abiotic degradation tetrachloroethane w...
# 65412  regulatory response mtbe threat groundwater re...
# 65413  warsyp robust modeling approach water resource...
# 65414  oxidative alteration spent fuel silicarich env...
# 65415  influence different methods derive soil hydrau...
# 65416  biotechnologies remediation pollution control ...
# 65417  intermediatescale lysimeter facility subsurfac...
# 65418  overview reentry clampon infill drilling incre...
# 65419  producing richgascondensate reservoirs case hi...
# 65420  successful west delta block redevelopment util...
# 65421  application streamline methodology saladin res...
# 65422  successful west delta block redevelopment util...
# 65423  mechanism effect chemical weathering sedimenta...
# 65424  inclusion performance model direct control sit...
# 65425  influence surfactants biosurfactants bioavaila...
# 65426  fate anthracene contaminated soil transport bi...
# 65427  spring season pattern nitraten herbicide movem...
# 65428  estimation potential loss two pesticides runof...
# 65429  conceptual uncertainties solubility calculatio...
# 65430  political environmental conflict development t...
# 65431  fissure behavior chihuahuan desert depth estim...
# 65432  integrated study judy field block overpressure...
# 65433  land farm design management bolivia casestudya...
#
#                                                      tdm  \
# 65384     abandoned  abundant  activity  alba  alone ...
# 65385     abroad  action  actions  agreements  alfld ...
# 65386     addition  analysis  assess  beyond  borehol...
# 65387     affect  also  amount  applied  complete  co...
# 65388     activity  ago  america  area  aucuparia  be...
# 65389     accurate  additional  adjacent  allow  anio...
# 65390     affecting  alpine  arctic  areas  biologica...
# 65391     accounts  accurately  allowing  also  aquif...
# 65392     additional  air  application  approaching  ...
# 65393     almost  also  alternative  appear  awwa  ba...
# 65394     aesthetic  andor  article  available  chemi...
# 65395     affecting  agreed  alcohols  alkyl  applica...
# 65396     adequate  analysis  associated  capable  ca...
# 65397     across  adler  advance  agency  argue  base...
# 65398     activated  advanced  borehole  buried  bwcs...
# 65399     analytical  artifacts  assessment  batch  c...
# 65400     able  amphipod  amphipods  analyses  analys...
# 65401     accuracy  accurate  affected  algorithm  ap...
# 65402     actual  also  analysis  analytical  analyze...
# 65403     actual  also  analysis  analytical  analyze...
# 65404     activation  adsorbate  adsorbents  adsorpti...
# 65405     accuracy  accurate  affected  algorithm  ap...
# 65406     anisotropic  application  approach  aquifer...
# 65407     accessed  addition  also  analyze  applicat...
# 65408     accumulate  activities  always  amendment  ...
# 65409     aerogenes  also  animal  area  around  asca...
# 65410     accumulation  around  atmosphere  axenic  b...
# 65411     aberdeen  abiotic  along  analyses  analyse...
# 65412     agencies  areas  assist  board  boards  cas...
# 65413     achieved  aim  algorithmic  allows  along  ...
# 65414     accurately  also  alterated  alteration  an...
# 65415     application  areas  calculated  catchment  ...
# 65416     acidic  advances  application  applications...
# 65417     ability  acceptors  adding  advantages  aer...
# 65418     activities  additional  also  analysis  aqu...
# 65419     agreed  allowed  approach  approachesthis  ...
# 65420     achieved  advanced  agip  alternative  appl...
# 65421     abandonment  achieved  advantages  almost  ...
# 65422     achieved  advanced  agip  alternative  appl...
# 65423     absent  acid  acidic  areas  base  bufferin...
# 65424     allows  analysis  approach  asce  associate...
# 65425     able  accumulation  activity  affinity  als...
# 65426     acid  activity  aerated  amount  anthracene...
# 65427     active  alluvial  along  among  analyzing  ...
# 65428     agricultural  areas  assessing  atrazine  b...
# 65429     account  actinide  also  analysis  answers ...
# 65430     achieve  activity  along  among  aquifers  ...
# 65431     aquifers  authors  base  become  behavior  ...
# 65432     accumulation  across  ago  allows  almost  ...
# 65433     abstract  acceptable  accomplished  additio...
#
#                                                countries
# 65384  ['united kingdom of great britain and northern...
# 65385  ['hungary', 'united kingdom of great britain a...
# 65386                                         ['canada']
# 65387                                                NaN
# 65388                                        ['iceland']
# 65389                       ['united states of america']
# 65390                             ['nigeria', 'iceland']
# 65391                       ['united states of america']
# 65392                                                NaN
# 65393                                                NaN
# 65394                                                NaN
# 65395                                                NaN
# 65396                                                NaN
# 65397                                                NaN
# 65398                                                NaN
# 65399                                                NaN
# 65400                                        ['germany']
# 65401               ['bolivia (plurinational state of)']
# 65402                           ['nigeria', 'indonesia']
# 65403                           ['nigeria', 'indonesia']
# 65404                                                NaN
# 65405               ['bolivia (plurinational state of)']
# 65406                                                NaN
# 65407                                                NaN
# 65408               ['bolivia (plurinational state of)']
# 65409                                                NaN
# 65410                                                NaN
# 65411                                                NaN
# 65412                                                NaN
# 65413                                                NaN
# 65414                                          ['congo']
# 65415                                        ['germany']
# 65416                                                NaN
# 65417                                                NaN
# 65418                                          ['india']
# 65419                                                NaN
# 65420                              ['nigeria', 'mexico']
# 65421                                      ['australia']
# 65422                              ['nigeria', 'mexico']
# 65423                                          ['japan']
# 65424                                                NaN
# 65425                                                NaN
# 65426                                                NaN
# 65427                       ['united states of america']
# 65428                       ['united states of america']
# 65429                                                NaN
# 65430                                         ['israel']
# 65431                       ['united states of america']
# 65432                                                NaN
# 65433                            ['argentina', 'norway']

# %%
df['aquifer_mentions'] = df['original_text'].apply(lambda x: match_aquifer_names(x))

# %%
display(df.head())
# Out:
#                                        original_text  \
# 0  FRACTURING AND SUBSIDENCE OF THE LAND SURFACE ...
# 1  An analysis of instabilities caused by salinit...
# 2  Pollution of the Rhine and water supply DutchA...
# 3  DEVELOPMENT AND IN PLACE LEACHING OF MOUNTAIN ...
# 4  The study of groundwater movement in boreholes...
#
#                                                 text  \
# 0  fracturing and subsidence of the land surface ...
# 1  an analysis of instabilities caused by salinit...
# 2  pollution of the rhine and water supply dutcha...
# 3  development and in place leaching of mountain ...
# 4  the study of groundwater movement in boreholes...
#
#                                       tokenized_text  \
# 0  ['fracturing', 'and', 'subsidence', 'of', 'the...
# 1  ['an', 'analysis', 'of', 'instabilities', 'cau...
# 2  ['pollution', 'of', 'the', 'rhine', 'and', 'wa...
# 3  ['development', 'and', 'in', 'place', 'leachin...
# 4  ['the', 'study', 'of', 'groundwater', 'movemen...
#
#                          no_stopwords_tokenized_text  \
# 0  ['fracturing', 'subsidence', 'land', 'surface'...
# 1  ['analysis', 'instabilities', 'caused', 'salin...
# 2  ['pollution', 'rhine', 'water', 'supply', 'dut...
# 3  ['development', 'place', 'leaching', 'mountain...
# 4  ['study', 'groundwater', 'movement', 'borehole...
#
#                                    no_stopwords_text  \
# 0  fracturing subsidence land surface caused with...
# 1  analysis instabilities caused salinity gradien...
# 2  pollution rhine water supply dutcha water supp...
# 3  development place leaching mountain city chalc...
# 4  study groundwater movement boreholes performed...
#
#                                                  tdm  \
# 0     amount  aquifers  area  artesian  bench  bo...
# 1     always  amplitude  analyse  analysis  aquif...
# 2     activities  almost  approximately  article ...
# 3     aid  analyzed  annualized  approximately  b...
# 4     among  aquifers  authors  avoiding  based  ...
#
#                                            countries aquifer_mentions
# 0                                                NaN              NaN
# 1                                                NaN              NaN
# 2  ['united kingdom of great britain and northern...              NaN
# 3                       ['united states of america']              NaN
# 4                                          ['spain']              NaN

# %%
counter = 0
matched = 0; 
for row in df.itertuples():
    #nan is type float
  if type(row[8])is not float:
#         print(row[8])
#         counter +=1
        matched += 1 
print(matched)
print(len(df.index))
print(matched/len(df.index))
# Out:
# 10538
# 65434
# 0.16104777332885045

# %%
print(df.loc[0, 'original_text'])

# %%
aquiferDf = df.dropna(subset=["aquifer_mentions"])
#aquiferDf["aquifer_mentions"].to_csv("../results/aquifer_names.csv")    
display(aquiferDf.head(10))
# Out:
#                                         original_text  \
# 8   AVAILABILITY OF WATER FOR COAL CONVERSIONCoal ...
# 25  COMPARATIVE ECONOMICS AND ENERGY REQUIREMENTS ...
# 27  Comparative economics and enrgy requirements o...
# 49  A Seismic Ground  Water Survey in New Hampshir...
# 58  STRATIGRAPHIC AND HYDROLOGIC RELATIONSHIP OF T...
# 60  Determining aquifer transmissivity by means of...
# 61  HYDROLOGIC ASPECTS OF STRIP MINING IN THE SUBB...
# 68  Gas Storage in Aquifers and Caverns GASSPEICHE...
# 72  Artificial recharge of aquifers and water qual...
# 74  Artificial recharge of aquifers and water qual...
#
#                                                  text  \
# 8   availability of water for coal conversioncoal ...
# 25  comparative economics and energy requirements ...
# 27  comparative economics and enrgy requirements o...
# 49  a seismic ground  water survey in new hampshir...
# 58  stratigraphic and hydrologic relationship of t...
# 60  determining aquifer transmissivity by means of...
# 61  hydrologic aspects of strip mining in the subb...
# 68  gas storage in aquifers and caverns gasspeiche...
# 72  artificial recharge of aquifers and water qual...
# 74  artificial recharge of aquifers and water qual...
#
#                                        tokenized_text  \
# 8   ['availability', 'of', 'water', 'for', 'coal',...
# 25  ['comparative', 'economics', 'and', 'energy', ...
# 27  ['comparative', 'economics', 'and', 'enrgy', '...
# 49  ['a', 'seismic', 'ground', 'water', 'survey', ...
# 58  ['stratigraphic', 'and', 'hydrologic', 'relati...
# 60  ['determining', 'aquifer', 'transmissivity', '...
# 61  ['hydrologic', 'aspects', 'of', 'strip', 'mini...
# 68  ['gas', 'storage', 'in', 'aquifers', 'and', 'c...
# 72  ['artificial', 'recharge', 'of', 'aquifers', '...
# 74  ['artificial', 'recharge', 'of', 'aquifers', '...
#
#                           no_stopwords_tokenized_text  \
# 8   ['availability', 'water', 'coal', 'conversionc...
# 25  ['comparative', 'economics', 'energy', 'requir...
# 27  ['comparative', 'economics', 'enrgy', 'require...
# 49  ['seismic', 'ground', 'water', 'survey', 'new'...
# 58  ['stratigraphic', 'hydrologic', 'relationship'...
# 60  ['determining', 'aquifer', 'transmissivity', '...
# 61  ['hydrologic', 'aspects', 'strip', 'mining', '...
# 68  ['gas', 'storage', 'aquifers', 'caverns', 'gas...
# 72  ['artificial', 'recharge', 'aquifers', 'water'...
# 74  ['artificial', 'recharge', 'aquifers', 'water'...
#
#                                     no_stopwords_text  \
# 8   availability water coal conversioncoal abundan...
# 25  comparative economics energy requirements vari...
# 27  comparative economics enrgy requirements vario...
# 49  seismic ground water survey new hampshirethe d...
# 58  stratigraphic hydrologic relationship piney po...
# 60  determining aquifer transmissivity means well ...
# 61  hydrologic aspects strip mining subbituminous ...
# 68  gas storage aquifers caverns gasspeicherung im...
# 72  artificial recharge aquifers water qualitythe ...
# 74  artificial recharge aquifers water qualitythe ...
#
#                                                   tdm  \
# 8      abundant  allocates  alternative  availabil...
# 25     alone  ana  annual  aquifers  assumed  avai...
# 27     alone  ana  annual  aquifers  assumed  avai...
# 49     according  along  anomalies  apparently  at...
# 58     acts  alloway  altitude  analyses  aquifer ...
# 60     almost  american  applicable  approximate  ...
# 61     almost  along  aquifer  aquifers  aspects  ...
# 68     according  aquifer  aquifers  author  avera...
# 72     aquifer  aquifers  artificial  basins  cons...
# 74     aquifer  aquifers  artificial  basins  ccb ...
#
#                                             countries  \
# 8                        ['united states of america']
# 25               ['peru', 'united states of america']
# 27               ['peru', 'united states of america']
# 49  ['united kingdom of great britain and northern...
# 58             ['jersey', 'united states of america']
# 60                                        ['america']
# 61                       ['united states of america']
# 68                                                NaN
# 72                                                NaN
# 74                                                NaN
#
#                                      aquifer_mentions
# 8      [Missouri River Basin, Fort UnionPowder Basin]
# 25                          [River groundwater basin]
# 27                          [River groundwater basin]
# 49    [HampshireThe drainage basin of Barbadoes Pond]
# 58  [Piney Point aquifer, Piney Point aquifer in C...
# 60                              [Determining aquifer]
# 61                             [Montana are aquifers]
# 68                              [Storage in Aquifers]
# 72                              [Vienne river basins]
# 74                              [Vienne river basins]

# %%
def match_usgs_list(arr):
    if(type(arr)) is float:
        return float('NaN')
    matches = []
    for element in arr:
        with open('../list_of_aquifer_names_usgs.text', 'r') as aquifer_names:
            for line in aquifer_names:
                if(line.lower() in element.lower()):
                     matches.append(line)
    if(len(matches) < 1):
        return float('NaN')
    return matches
