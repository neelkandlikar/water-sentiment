# %%
import pandas as pd
import csv
from IPython.display import display

# %%
df = pd.read_csv("../data/abstracts_chunk_1.csv",quoting=csv.QUOTE_ALL)

# %%
display(df.head())
print(df.columns.values)
print(len(df.index))
# Out:
#    Unnamed: 0             abstracts-retrieval-response.@xmlns  \
# 0           0  http://www.elsevier.com/xml/svapi/abstract/dtd
# 1           0  http://www.elsevier.com/xml/svapi/abstract/dtd
# 2           0  http://www.elsevier.com/xml/svapi/abstract/dtd
# 3           0  http://www.elsevier.com/xml/svapi/abstract/dtd
# 4           0  http://www.elsevier.com/xml/svapi/abstract/dtd
#
#            abstracts-retrieval-response.@xmlns:dn  \
# 0  http://www.elsevier.com/xml/svapi/abstract/dtd
# 1  http://www.elsevier.com/xml/svapi/abstract/dtd
# 2  http://www.elsevier.com/xml/svapi/abstract/dtd
# 3  http://www.elsevier.com/xml/svapi/abstract/dtd
# 4  http://www.elsevier.com/xml/svapi/abstract/dtd
#
#   abstracts-retrieval-response.@xmlns:ait  \
# 0     http://www.elsevier.com/xml/ani/ait
# 1     http://www.elsevier.com/xml/ani/ait
# 2     http://www.elsevier.com/xml/ani/ait
# 3     http://www.elsevier.com/xml/ani/ait
# 4     http://www.elsevier.com/xml/ani/ait
#
# ...

# %%
print(df.loc[2, 'abstracts-retrieval-response.coredata.dc:description.abstract.ce:para'])
df = df[df['abstracts-retrieval-response.coredata.dc:description.abstract.ce:para'].str.lower() != "nan"]
print(len(df.index))
# Out:
# A water supply company is probably the only type of company which cannot lay down stringent regulations as regards the quality of its raw materials and at the same time meet strict quality regulations for its end product. After sketching quantity and quality of the Dutch water resources (industry uses almost as much as the drinking water supply companies) a general outline of the surface water situation is given. Approximately 70% of all surface water entering the Netherlands comes in with the Rhine. Whereas ground water problems mostly involve quantity considerations, surface water exploitation meets quality problems. An overview of the activities of the 2 principal bodies concerned with Rhine water purity (International Rhine Commission, EEC Council) concludes the article.
# 10000
