# %% [markdown]
# ### imports

# %%
import pandas as pd
import csv
from IPython.display import display, clear_output

# %% [markdown]
# ### Loading Data and setting Jupyter defaults

# %%
# Read in chunked abstract data
df = pd.read_csv("../data/abstracts_chunk_1.csv",quoting=csv.QUOTE_ALL)
# Out:
# /Users/neel/opt/anaconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3058: DtypeWarning: Columns (81,87,91,92) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
# Preliminary df Visualizations
pd.set_option('display.max_columns', 999)
print(df.columns.values)
print(len(df.index))
# Out:
# ['Unnamed: 0' 'abstracts-retrieval-response.@xmlns'
#  'abstracts-retrieval-response.@xmlns:dn'
#  'abstracts-retrieval-response.@xmlns:ait'
#  'abstracts-retrieval-response.@xmlns:ce'
#  'abstracts-retrieval-response.@xmlns:cto'
#  'abstracts-retrieval-response.@xmlns:dc'
#  'abstracts-retrieval-response.@xmlns:prism'
#  'abstracts-retrieval-response.@xmlns:xocs'
#  'abstracts-retrieval-response.@xmlns:xsi'
#  'abstracts-retrieval-response.coredata.prism:url'
#  'abstracts-retrieval-response.coredata.dc:identifier'
#  'abstracts-retrieval-response.coredata.eid'
#  'abstracts-retrieval-response.coredata.dc:title'
#  'abstracts-retrieval-response.coredata.prism:aggregationType'
#  'abstracts-retrieval-response.coredata.srctype'
#  'abstracts-retrieval-response.coredata.subtype'
#  'abstracts-retrieval-response.coredata.subtypeDescription'
#  'abstracts-retrieval-response.coredata.citedby-count'
#  'abstracts-retrieval-response.coredata.prism:publicationName'
# ...

# %% [markdown]
# ### Printing and Displaying Data

# %%
# Understanding the structure and contents of the data
print(df.loc[2, 'abstracts-retrieval-response.coredata.dc:description.abstract.ce:para'])
display(df.head())
# Out:
# A water supply company is probably the only type of company which cannot lay down stringent regulations as regards the quality of its raw materials and at the same time meet strict quality regulations for its end product. After sketching quantity and quality of the Dutch water resources (industry uses almost as much as the drinking water supply companies) a general outline of the surface water situation is given. Approximately 70% of all surface water entering the Netherlands comes in with the Rhine. Whereas ground water problems mostly involve quantity considerations, surface water exploitation meets quality problems. An overview of the activities of the 2 principal bodies concerned with Rhine water purity (International Rhine Commission, EEC Council) concludes the article.
#    Unnamed: 0             abstracts-retrieval-response.@xmlns  \
# 0           0  http://www.elsevier.com/xml/svapi/abstract/dtd
# 1           0  http://www.elsevier.com/xml/svapi/abstract/dtd
# ...

# %%
#get column number of abstract

# arr = df.columns.values
# for i in range(0,len(arr)):
#     if arr[i] == "abstracts-retrieval-response.coredata.dc:description.abstract.ce:para":
#         print(i)
print(len(df.index))
# Out:
# 10000

# %%
#drop rows with nan abstracts
df = df.dropna(subset=['abstracts-retrieval-response.coredata.dc:description.abstract.ce:para'])
print(len(df.index))

# Reading some abstracts to familiarize with geospatial content.
count = 0 
for row in df.itertuples():
    if count >= 10:
        break  
    print(row[44])
    print("***")
    count += 1
# Out:
# 7183
# Land subsidence in the Milford area is demonstrated by three lines of evidence: (1) collapse structures, (2) well casings that protrude higher above the land surface than when first placed in the borehole, and (3) lower elevations at National Ocean Survey (formerly U. S. Coast and Geodetic Survey) bench marks in 1970 than in 1908. This evidence shows that land subsidence in the Milford area is of two types, each having a different origin. One type has a near-surface origin in the clay-silt zone in the upper part of the principal groundwater reservoir, and the other is in the lower artesian aquifers of the principal groundwater reservoir. The amount of observed subsidence ranges from 0. 05 ft (0. 015 m) at the bench mark at Read to about 6 ft (1. 8 m) at collapse structures in the Hay Springs area.
# ***
# ...
