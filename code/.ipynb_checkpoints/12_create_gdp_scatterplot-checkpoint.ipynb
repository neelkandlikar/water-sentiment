# %%
import pandas as pd
import re
import csv
from IPython.display import display, clear_output
import geopandas
from ast import literal_eval
import math
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
import plotly.express as px
# %matplotlib inline

# %%
def format_element(element):
    country_reformat = {
        'america': 'united states',
        'united states of america':'united states',
        'USA': 'united states',
        'congo' : 'congo, dem. rep.',
        'egypt' : 'egypt, arab rep.',
        'yemen' : 'yemen, rep.',
        'bahamas' : 'bahamas, the',
        'russia' : 'russian federation',
        'united kingdom of great britain and northern ireland': 'united kingdom'
    }
    
    if element in country_reformat:
        return country_reformat[element]
    return element

# %%
def join_abstract_country_country_counts(og_df, new_df, new_df_country_column_name,og_df_country_index):
    matched = []
    review = ["united kingdom","russia", "korea", "iran"]
    new_df['Occurrences'] = 0
    for row in og_df.itertuples():
        countries = row[og_df_country_index]
        countries = literal_eval(countries)
        for element in countries:
            element = format_element(element)
    
            if new_df[new_df_country_column_name].str.contains(element).any():
                for i in review:
                    if i in element:
                        print(element)
                row_number = new_df[new_df[new_df_country_column_name] == element].index[0]
                new_df.loc[row_number, 'Occurrences'] +=1
            if gdp[new_df_country_column_name].str.contains(element).any() and element not in matched:
                matched.append(element)
    print(matched)
    new_df.head()

# %%
df = pd.read_csv("../dataframes/12_2_capital_algorithms.csv")
print(len(df.index)
df = df.dropna(subset=['countries'])
display(df.head())
# Out:
# 65434
# FRACTURING AND SUBSIDENCE OF THE LAND SURFACE CAUSED BY THE WITHDRAWAL OF GROUND WATER IN THE MILFORD AREA UTAHLand subsidence in the Milford area is demonstrated by three lines of evidence  collapse structures  well casings that protrude higher above the land surface than when first placed in the borehole and  lower elevations at National Ocean Survey formerly U S Coast and Geodetic Survey bench marks in  than in  This evidence shows that land subsidence in the Milford area is of two types each having a different origin One type has a nearsurface origin in the claysilt zone in the upper part of the principal groundwater reservoir and the other is in the lower artesian aquifers of the principal groundwater reservoir The amount of observed subsidence ranges from   ft   m at the bench mark at Read to about  ft   m at collapse structures in the Hay Springs area
# ...

# %%
gdp = pd.read_csv("../world_bank_gdp.csv", encoding="cp1252")

# %%
gdp = gdp.iloc[4:]
gdp = gdp.drop('Unnamed: 5', 1)
display(gdp.head(20))
# Out:
#    Unnamed: 0 Gross domestic product 2019  Unnamed: 2          Unnamed: 3  \
# 4         USA                           1         NaN       United States
# 5         CHN                           2         NaN               China
# 6         JPN                           3         NaN               Japan
# 7         DEU                           4         NaN             Germany
# 8         IND                           5         NaN               India
# 9         GBR                           6         NaN      United Kingdom
# 10        FRA                           7         NaN              France
# 11        ITA                           8         NaN               Italy
# 12        BRA                           9         NaN              Brazil
# 13        CAN                          10         NaN              Canada
# 14        RUS                          11         NaN  Russian Federation
# 15        KOR                          12         NaN         Korea, Rep.
# ...

# %%
gdp = gdp.drop('Unnamed: 2', 1)
gdp.columns = ["Abbreviation", "Ranking", "Country", "GDP"]
display(gdp.head())
# Out:
#   Abbreviation Ranking        Country           GDP
# 4          USA       1  United States   21,427,700
# 5          CHN       2          China   14,342,903
# 6          JPN       3          Japan    5,081,770
# 7          DEU       4        Germany    3,845,630
# 8          IND       5          India    2,875,142

# %%
gdp = gdp.reset_index(drop=True)

# %%
gdp["Country"] = gdp["Country"].str.lower()

# %%
gdp.head()
# Out:
#   Abbreviation Ranking        Country           GDP
# 0          USA       1  united states   21,427,700
# 1          CHN       2          china   14,342,903
# 2          JPN       3          japan    5,081,770
# 3          DEU       4        germany    3,845,630
# 4          IND       5          india    2,875,142

# %%
join_abstract_country_country_counts(df, gdp, "Country", 8)
# Out:
# united kingdom
# united kingdom
# united kingdom
# united kingdom
# united kingdom
# united kingdom
# united kingdom
# united kingdom
# united kingdom
# united kingdom
# united kingdom
# united kingdom
# united kingdom
# united kingdom
# united kingdom
# united kingdom
# united kingdom
# united kingdom
# united kingdom
# united kingdom
# united kingdom
# united kingdom
# united kingdom
# united kingdom
# united kingdom
# united kingdom
# united kingdom
# united kingdom
# united kingdom
# united kingdom
# united kingdom
# united kingdom
# united kingdom
# united kingdom
# united kingdom
# united kingdom
# united kingdom
# united kingdom
# united kingdom
# united kingdom
# united kingdom
# united kingdom
# united kingdom
# united kingdom
# united kingdom
# united kingdom
# united kingdom
# united kingdom
# united kingdom
# united kingdom
# united kingdom
# united kingdom
# united kingdom
# united kingdom
# united kingdom
# united kingdom
# united kingdom
# united kingdom
# ...

# %%
display(gdp.head(10))
# Out:
#   Abbreviation Ranking         Country           GDP  Occurrences
# 0          USA       1   united states   21,427,700          9826
# 1          CHN       2           china   14,342,903          2816
# 2          JPN       3           japan    5,081,770           840
# 3          DEU       4         germany    3,845,630          2039
# 4          IND       5           india    2,875,142          2616
# 5          GBR       6  united kingdom    2,827,113          2068
# 6          FRA       7          france    2,715,518           477
# 7          ITA       8           italy    2,001,244           612
# 8          BRA       9          brazil    1,839,758           468
# 9          CAN      10          canada    1,736,426          1301

# %%
blank_gdp = gdp.loc[gdp['Occurrences'] == 0]
display(blank_gdp.head(5))
# Out:
#    Abbreviation Ranking               Country          GDP  Occurrences
# 11          KOR      12           korea, rep.   1,642,383             0
# 17          SAU      18          saudi arabia     792,967             0
# 27          IRN      28    iran, islamic rep.     445,345             0
# 28          ARE      29  united arab emirates     421,142             0
# 34          HKG      35  hong kong sar, china     366,030             0

# %%
gdp['GDP'] = gdp['GDP'].str.strip()
gdp['GDP'] = gdp['GDP'].replace(',','', regex=True)
gdp['GDP'] = gdp['GDP'].replace('-','', regex=True)
gdp['GDP'] = gdp['GDP'].replace('','0', regex=True)

gdp['GDP'] = gdp['GDP'].astype(int)

# %%
gdp.head()
# Out:
#   Abbreviation Ranking        Country       GDP  Occurrences
# 0          USA       1  united states  21427700         9826
# 1          CHN       2          china  14342903         2816
# 2          JPN       3          japan   5081770          840
# 3          DEU       4        germany   3845630         2039
# 4          IND       5          india   2875142         2616

# %%
gdp['Occurrences'] = gdp['Occurrences'].astype(int)

# %%
# x = gdp.GDP
# print(x.dtype)
# y = gdp.Occurrences
# print(type(y.dtype))
# # plt.figure(figsize=(100, 20), dpi=80)
# # fig, ax = plt.subplots()
# plt.scatter(x,y)
# plt.show()
# gdp.plot.scatter(x = 'GDP', y = 'Occurrences')
# gdp.plot.scatter(x = 'GDP', y='Occurrences')
gdp['Country_Title'] = gdp['Country'].str.title()
gdp.head()
# Out:
#   Abbreviation Ranking        Country       GDP  Occurrences  Country_Title
# 0          USA       1  united states  21427700         9826  United States
# 1          CHN       2          china  14342903         2816          China
# 2          JPN       3          japan   5081770          840          Japan
# 3          DEU       4        germany   3845630         2039        Germany
# 4          IND       5          india   2875142         2616          India

# %%
gdp.rename(columns={'Occurrences':'Abstracts'}, inplace=True)
gdp.head()
# Out:
#   Abbreviation Ranking        Country       GDP  Abstracts  Country_Title
# 0          USA       1  united states  21427700       9826  United States
# 1          CHN       2          china  14342903       2816          China
# 2          JPN       3          japan   5081770        840          Japan
# 3          DEU       4        germany   3845630       2039        Germany
# 4          IND       5          india   2875142       2616          India

# %%
fig = px.scatter(gdp, x="GDP", y="Abstracts", hover_name = "Country_Title", trendline="ols")
fig.show()
# Out:
# <div>                            <div id="b8c46201-34b1-4a28-895a-57bb846a9aa7" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("b8c46201-34b1-4a28-895a-57bb846a9aa7")) {                    Plotly.newPlot(                        "b8c46201-34b1-4a28-895a-57bb846a9aa7",                        [{"hovertemplate": "<b>%{hovertext}</b><br><br>GDP=%{x}<br>Abstracts=%{y}<extra></extra>", "hovertext": ["United States", "China", "Japan", "Germany", "India", "United Kingdom", "France", "Italy", "Brazil", "Canada", "Russian Federation", "Korea, Rep.", "Spain", "Australia", "Mexico", "Indonesia", "Netherlands", "Saudi Arabia", "Turkey", "Switzerland", "Poland", "Thailand", "Sweden", "Belgium", "Argentina", "Nigeria", "Austria", "Iran, Islamic Rep.", "United Arab 
# ...

# %%
fig.write_html("../plots/abstracts_vs_gdp.html")

# %%
high_occur = gdp.loc[gdp['Abstracts'] >= 1900]
display(high_occur.head(10))
# Out:
#    Abbreviation Ranking         Country       GDP  Abstracts   Country_Title
# 0           USA       1   united states  21427700       9826   United States
# 1           CHN       2           china  14342903       2816           China
# 3           DEU       4         germany   3845630       2039         Germany
# 4           IND       5           india   2875142       2616           India
# 5           GBR       6  united kingdom   2827113       2068  United Kingdom
# 25          NGA      26         nigeria    448120       3053         Nigeria
